# %%
#import required libraries
from flask import Flask, render_template, json, jsonify, Response, request, redirect
import requests
from bs4 import BeautifulSoup  
from textblob import TextBlob
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.probability import FreqDist
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ozank\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ozank\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ozank\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
URL = 'https://rss.nytimes.com/services/xml/rss/nyt/World.xml'

# %%
def wordCount(tdesc):
    text = re.sub('<[^<]+?>', '', tdesc)
    text = text.lower()
    text = text.replace('"','')
    text = text.replace('“','')
    text = text.replace('”','')
    text = text.replace("’",'')

    strip = str.maketrans('','', string.punctuation)
    text = text.translate(strip)

    tokenized_word=word_tokenize(text)
    tokenized_word = [word.lower() for word in tokenized_word]

    stop_words = set(stopwords.words('english'))
    filtered_word = []

    for word in tokenized_word:
        if word not in stop_words:
            filtered_word.append(word)

    lem = WordNetLemmatizer()
    lem_words = []
    for w in filtered_word:
        lem_words.append(lem.lemmatize(w,'v'))

    fdist = FreqDist(lem_words)
    most_common = fdist.most_common(100)
    wcDict = []
    for item in most_common:
        res = {'word' : item[0], 'count': item[1]}
        wcDict.append(res)
    return wcDict

# %%
newsURL = URL
    
newsGet = requests.get(newsURL)
newsSoup = BeautifulSoup(newsGet.content, features='xml')
news = newsSoup.findAll('item')
totalDescription = ''

newsArticles = []
for article in news:
    newsArticle = {}
    newsArticle['title'] = article.title.text
    newsArticle['description'] = article.description.text
    newsArticle['link'] = article.link.text
    newsArticle['date'] = article.pubDate.text
        

    useBlob = article.title.text
    blob = TextBlob(useBlob) 
    newsArticle['polarity'] = blob.sentiment.polarity
        
    if newsArticle['polarity'] > 0:
        newsArticle['sentiment'] = 'Positive'
    elif newsArticle['polarity'] < 0:
        newsArticle['sentiment'] = 'Negative'
    else:
        newsArticle['sentiment'] = 'Neutral'

    newsArticles.append(newsArticle)
    totalDescription += newsArticle['description']

df = pd.DataFrame(newsArticles,columns=['title','description','link','date','polarity','sentiment'])
rDict = wordCount(totalDescription)

# %%
df.head()
# Out:
#                                                title  \
# 0  British Columbia's Flooding Is Worse Because o...
# 1  In Hard Times, Afghan Farmers Are Turning to O...
# 2        Chileans Will Vote For President on Sunday
# 3  Ousted in Coup, Sudan’s Prime Minister Returns...
# 4  Israeli Is Killed by Palestinian Near Holiest ...
#
#                                          description  \
# 0  After a summer of deadly heat and uncontrolled...
# 1  The war’s intense conclusion and a drought com...
# 2  The top contenders to lead Chile out of a turb...
# 3  Four weeks after he was detained, Prime Minist...
# 4  The shooting, the first attack by a Palestinia...
#
#                                                 link  \
# 0  https://www.nytimes.com/2021/11/21/canada-floo...
# 1  https://www.nytimes.com/2021/11/21/world/asia/...
# 2  https://www.nytimes.com/2021/11/21/world/ameri...
# 3  https://www.nytimes.com/2021/11/21/world/afric...
# 4  https://www.nytimes.com/2021/11/21/world/middl...
#
#                               date  polarity sentiment
# 0  Sun, 21 Nov 2021 15:46:22 +0000 -0.200000  Negative
# 1  Sun, 21 Nov 2021 19:59:33 +0000 -0.291667  Negative
# 2  Sun, 21 Nov 2021 16:03:40 +0000  0.000000   Neutral
# 3  Sun, 21 Nov 2021 20:11:49 +0000 -0.100000  Negative
# 4  Sun, 21 Nov 2021 19:34:48 +0000 -0.050000  Negative

# %%
rDict
# Out:
# [{'word': 'say', 'count': 11},
#  {'word': 'president', 'count': 6},
#  {'word': 'officials', 'count': 5},
#  {'word': 'country', 'count': 5},
#  {'word': 'would', 'count': 4},
#  {'word': 'new', 'count': 4},
#  {'word': 'government', 'count': 4},
#  {'word': 'state', 'count': 4},
#  {'word': 'people', 'count': 4},
#  {'word': 'two', 'count': 4},
#  {'word': 'help', 'count': 4},
#  {'word': 'meet', 'count': 3},
#  {'word': 'side', 'count': 3},
#  {'word': 'monday', 'count': 3},
#  {'word': 'sign', 'count': 3},
#  {'word': 'conflict', 'count': 3},
#  {'word': 'border', 'count': 3},
#  {'word': 'trap', 'count': 3},
#  {'word': 'year', 'count': 3},
#  {'word': 'one', 'count': 3},
#  {'word': 'days', 'count': 3},
#  {'word': 'least', 'count': 3},
#  {'word': 'since', 'count': 3},
#  {'word': 'countrys', 'count': 3},
#  {'word': 'duterte', 'count': 3},
#  {'word': 'kill', 'count': 3},
#  {'word': 'military', 'count': 3},
#  {'word': 'experts', 'count': 3},
#  {'word': 'men', 'count': 3},
#  {'word': 'surge', 'count': 3},
#  {'word': 'last', 'count': 3},
#  {'word': 'biden', 'count': 2},
#  {'word': 'chinas', 'count': 2},
#  {'word': 'xi', 'count': 2},
#  {'word': 'hours', 'count': 2},
#  {'word': 'reassure', 'count': 2},
#  {'word': 'misunderstand', 'count': 2},
#  {'word': 'lead', 'count': 2},
#  {'word': 'unintended', 'count': 2},
#  {'word': 'dispute', 'count': 2},
#  {'word': 'fight', 'count': 2},
#  {'word': 'europe', 'count': 2},
#  {'word': 'syrian', 'count': 2},
#  {'word': 'aleksandr', 'count': 2},
#  {'word': 'g', 'count': 2},
#  {'word': 'thousands', 'count': 2},
#  {'word': 'tons', 'count': 2},
#  {'word': 'may', 'count': 2},
#  {'word': 'fuel', 'count': 2},
#  {'word': 'line', 'count': 2},
#  {'word': 'part', 'count': 2},
#  {'word': 'make', 'count': 2},
#  {'word': 'life', 'count': 2},
#  {'word': 'protest', 'count': 2},
#  {'word': 'home', 'count': 2},
#  {'word': 'police', 'count': 2},
#  {'word': 'human', 'count': 2},
#  {'word': 'right', 'count': 2},
#  {'word': 'tear', 'count': 2},
#  {'word': 'violence', 'count': 2},
#  {'word': 'leaders', 'count': 2},
#  {'word': 'burn', 'count': 2},
#  {'word': 'vice', 'count': 2},
#  {'word': 'previously', 'count': 2},
#  {'word': 'vaccine', 'count': 2},
#  {'word': 'investigation', 'count': 2},
#  {'word': 'find', 'count': 2},
#  {'word': 'bomb', 'count': 2},
#  {'word': 'seek', 'count': 2},
#  {'word': 'extend', 'count': 2},
#  {'word': 'keep', 'count': 2},
#  {'word': 'call', 'count': 2},
#  {'word': 'biggest', 'count': 2},
#  {'word': 'covid', 'count': 2},
#  {'word': 'suffer', 'count': 2},
#  {'word': 'health', 'count': 2},
#  {'word': 'remote', 'count': 2},
#  {'word': '—', 'count': 2},
#  {'word': 'issue', 'count': 2},
#  {'word': 'number', 'count': 2},
#  {'word': 'virus', 'count': 2},
#  {'word': 'case', 'count': 2},
#  {'word': 'climate', 'count': 2},
#  {'word': 'migrants', 'count': 2},
#  {'word': 'belarus', 'count': 2},
#  {'word': 'iraqi', 'count': 2},
#  {'word': 'several', 'count': 2},
#  {'word': 'elqaddafi', 'count': 2},
#  {'word': 'sunday', 'count': 2},
#  {'word': 'province', 'count': 2},
#  {'word': 'pandemic', 'count': 2},
#  {'word': 'put', 'count': 2},
#  {'word': 'die', 'count': 2},
#  {'word': 'loss', 'count': 2},
#  {'word': 'attack', 'count': 2},
#  {'word': 'rely', 'count': 2},
#  {'word': 'little', 'count': 2},
#  {'word': 'worlds', 'count': 2},
#  {'word': 'force', 'count': 2},
#  {'word': 'many', 'count': 2}]

# %%
df.to_csv("sentimentdata.csv", encoding='utf-8', index=False)

# %%
# Out:
# Azure Blob Storage v12.9.0 - Python quickstart sample
# None
